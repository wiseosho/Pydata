# %%
import pandas as pd

#read_csv ,
#read_table \t
#read_fwf width

# !cat ./pydata-book/ch06/ex1.csv
# Out:
# a,b,c,d,message
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo

# %%
df = pd.read_csv('./pydata-book/ch06/ex1.csv')

# %%
df_tbl = pd.read_table('./pydata-book/ch06/ex1.csv', sep = ',')

# %%
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
df_nohead = pd.read_csv('./pydata-book/ch06/ex1.csv',header=None)
df_nohead
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
names = ['a', 'b', 'c', 'd', 'message']

pd.read_csv('./pydata-book/ch06/ex2.csv', names=names, index_col = 'message')
# Out:
#          a   b   c   d
# message
# hello    1   2   3   4
# world    5   6   7   8
# foo      9  10  11  12

# %%
# !cat ./pydata-book/ch06/csv_mindex.csv
# Out:
# key1,key2,value1,value2
# one,a,1,2
# one,b,3,4
# one,c,5,6
# one,d,7,8
# two,a,9,10
# two,b,11,12
# two,c,13,14
# two,d,15,16

# %%
parsed = pd.read_csv('./pydata-book/ch06/csv_mindex.csv', index_col = ['key1', 'key2'])

parsed
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
list(open('./pydata-book/ch06/ex3.txt'))
# Out:
# ['            A         B         C\n',
#  'aaa -0.264438 -1.026059 -0.619500\n',
#  'bbb  0.927272  0.302904 -0.032399\n',
#  'ccc -0.264273 -0.386314 -0.217601\n',
#  'ddd -0.871858 -0.348382  1.100491\n']

# %%
#variable whitespaces
result = pd.read_table('./pydata-book/ch06/ex3.txt',sep = '\s+')
result

# %%
# !cat ./pydata-book/ch06/ex4.csv
# Out:
# # hey!
# a,b,c,d,message
# # just wanted to make things more difficult for you
# # who reads CSV files with computers, anyway?
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo

# %%
pd.read_csv('./pydata-book/ch06/ex4.csv')
# Out:
#                                                                       # hey!
# a                                                  b        c   d    message
# # just wanted to make things more difficult for... NaN      NaN NaN      NaN
# # who reads CSV files with computers                anyway? NaN NaN      NaN
# 1                                                  2        3   4      hello
# 5                                                  6        7   8      world
# 9                                                  10       11  12       foo

# %%
pd.read_csv('./pydata-book/ch06/ex4.csv', skiprows=[0,2,3])
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# !cat ./pydata-book/ch06/ex5.csv
# Out:
# something,a,b,c,d,message
# one,1,2,3,4,NA
# two,5,6,,8,world
# three,9,10,11,12,foo

# %%
result = pd.read_csv('./pydata-book/ch06/ex5.csv')
result
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
result.isnull()
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
result.notnull()
# Out:
#    something     a     b      c     d  message
# 0       True  True  True   True  True    False
# 1       True  True  True  False  True     True
# 2       True  True  True   True  True     True

# %%
pd.read_csv('./pydata-book/ch06/ex5.csv', na_values = ['NULL'])
#
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
#?????
sentinels = {'message' : ['foo', 'NA'], 'something': ['two']}  #????

sent = pd.read_csv('./pydata-book/ch06/ex5.csv', na_values = sentinels)

sent
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       NaN  5   6   NaN   8   world
# 2     three  9  10  11.0  12     NaN

# %%
result = pd.read_csv('./pydata-book/ch06/ex6.csv')

result
# Out:
#            one       two     three      four key
# 0     0.467976 -0.038649 -0.295344 -1.824726   L
# 1    -0.358893  1.404453  0.704965 -0.200638   B
# 2    -0.501840  0.659254 -0.421691 -0.057688   G
# 3     0.204886  1.074134  1.388361 -0.982404   R
# 4     0.354628 -0.133116  0.283763 -0.837063   Q
# 5     1.817480  0.742273  0.419395 -2.251035   Q
# 6    -0.776764  0.935518 -0.332872 -1.875641   U
# 7    -0.913135  1.530624 -0.572657  0.477252   K
# 8     0.358480 -0.497572 -0.367016  0.507702   S
# 9    -1.740877 -1.160417 -1.637830  2.172201   G
# 10    0.240564 -0.328249  1.252155  1.072796   8
# 11    0.764018  1.165476 -0.639544  1.495258   R
# 12    0.571035 -0.310537  0.582437 -0.298765   1
# 13    2.317658  0.430710 -1.334216  0.199679   P
# 14    1.547771 -1.119753 -2.277634  0.329586   J
# 15   -1.310608  0.401719 -1.000987  1.156708   E
# 16   -0.088496  0.634712  0.153324  0.415335   B
# 17   -0.018663 -0.247487 -1.446522  0.750938   A
# ...

# %%
#Partial buffering, nrows
pd.read_csv('./pydata-book/ch06/ex6.csv', nrows=5)
# Out:
#         one       two     three      four key
# 0  0.467976 -0.038649 -0.295344 -1.824726   L
# 1 -0.358893  1.404453  0.704965 -0.200638   B
# 2 -0.501840  0.659254 -0.421691 -0.057688   G
# 3  0.204886  1.074134  1.388361 -0.982404   R
# 4  0.354628 -0.133116  0.283763 -0.837063   Q

# %%
chunker = pd.read_csv('./pydata-book/ch06/ex6.csv', chunksize=1000)

# %%
tot = pd.Series([])

# %%
for piece in chunker:
    print (piece)
    print (piece['key'].value_counts())
    tot = tot.add(piece['key'].value_counts(), fill_value=0)
# Out:
#           one       two     three      four key
# 0    0.467976 -0.038649 -0.295344 -1.824726   L
# 1   -0.358893  1.404453  0.704965 -0.200638   B
# 2   -0.501840  0.659254 -0.421691 -0.057688   G
# 3    0.204886  1.074134  1.388361 -0.982404   R
# 4    0.354628 -0.133116  0.283763 -0.837063   Q
# 5    1.817480  0.742273  0.419395 -2.251035   Q
# 6   -0.776764  0.935518 -0.332872 -1.875641   U
# 7   -0.913135  1.530624 -0.572657  0.477252   K
# 8    0.358480 -0.497572 -0.367016  0.507702   S
# 9   -1.740877 -1.160417 -1.637830  2.172201   G
# 10   0.240564 -0.328249  1.252155  1.072796   8
# 11   0.764018  1.165476 -0.639544  1.495258   R
# 12   0.571035 -0.310537  0.582437 -0.298765   1
# 13   2.317658  0.430710 -1.334216  0.199679   P
# 14   1.547771 -1.119753 -2.277634  0.329586   J
# 15  -1.310608  0.401719 -1.000987  1.156708   E
# 16  -0.088496  0.634712  0.153324  0.415335   B
# 17  -0.018663 -0.247487 -1.446522  0.750938   A
# 18  -0.070127 -1.579097  0.120892  0.671432   F
# ...

# %%
#tot.order X 
# -> tot.sort_index(ascending=False)

tot.sort_index(ascending=False)
# Out:
# Z    288.0
# Y    314.0
# X    364.0
# W    305.0
# V    328.0
# U    326.0
# T    304.0
# S    308.0
# R    318.0
# Q    340.0
# P    324.0
# O    343.0
# N    306.0
# M    338.0
# L    346.0
# K    334.0
# J    337.0
# I    327.0
# H    330.0
# G    308.0
# F    335.0
# E    368.0
# D    320.0
# C    286.0
# B    302.0
# A    320.0
# 9    150.0
# 8    162.0
# 7    164.0
# 6    166.0
# 5    157.0
# 4    171.0
# 3    162.0
# 2    152.0
# 1    146.0
# 0    151.0
# dtype: float64

# %%
tot.sort_index(ascending=False)[:10]
# Out:
# Z    288.0
# Y    314.0
# X    364.0
# W    305.0
# V    328.0
# U    326.0
# T    304.0
# S    308.0
# R    318.0
# Q    340.0
# dtype: float64

# %%
tot.sort_values()[:10]
# Out:
# 1    146.0
# 9    150.0
# 0    151.0
# 2    152.0
# 5    157.0
# 3    162.0
# 8    162.0
# 7    164.0
# 6    166.0
# 4    171.0
# dtype: float64

# %%
data = pd.read_csv('./pydata-book/ch06/ex5.csv')

data
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
data.to_csv('./pydata-book/6out.csv')

# %%
# !cat ./pydata-book/6out.csv
# Out:
# ,something,a,b,c,d,message
# 0,one,1,2,3.0,4,
# 1,two,5,6,,8,world
# 2,three,9,10,11.0,12,foo

# %%
import sys
#print out to stdout.
data.to_csv(sys.stdout, sep='|')
# Out:
# |something|a|b|c|d|message
# 0|one|1|2|3.0|4|
# 1|two|5|6||8|world
# 2|three|9|10|11.0|12|foo

# %%
# Replace np.nan with string 'NULL'
data.to_csv(sys.stdout, na_rep = 'NULL')
# Out:
# ,something,a,b,c,d,message
# 0,one,1,2,3.0,4,NULL
# 1,two,5,6,NULL,8,world
# 2,three,9,10,11.0,12,foo

# %%
# Repeat Na's with 'NO'
data.to_csv(sys.stdout, na_rep = 'NO')
# Out:
# ,something,a,b,c,d,message
# 0,one,1,2,3.0,4,NO
# 1,two,5,6,NO,8,world
# 2,three,9,10,11.0,12,foo

# %%
#Don't export Headers
data.to_csv(sys.stdout, index = False, header = False)
# Out:
# one,1,2,3.0,4,
# two,5,6,,8,world
# three,9,10,11.0,12,foo

# %%
#
data.to_csv(sys.stdout, index=False, cols = ['a', 'b', 'c'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-289baedfdb5b> in <module>()
# ----> 1 data.to_csv(sys.stdout, index=False, cols = ['a', 'b', 'c'])
#
# TypeError: to_csv() got an unexpected keyword argument 'cols'

# %%
import numpy as np

dates = pd.date_range('1/1/2000', periods = 7)

ts = pd.Series(np.arange(7), index = dates)

ts.to_csv('./pydata-book/ch06/tseries.csv')

# !cat ./pydata-book/ch06/tseries.csv
# Out:
# 2000-01-01,0
# 2000-01-02,1
# 2000-01-03,2
# 2000-01-04,3
# 2000-01-05,4
# 2000-01-06,5
# 2000-01-07,6

# %%
pd.date_range('1/1/2000', periods= 7)
#periods how long
ts = pd.Series(np.arange(7), index = pd.date_range('1/1/2000', periods=7))

ts.to_csv(sys.stdout)
# Out:
# 2000-01-01,0
# 2000-01-02,1
# 2000-01-03,2
# 2000-01-04,3
# 2000-01-05,4
# 2000-01-06,5
# 2000-01-07,6

# %%
# !cat ./pydata-book/ch06/ex7.csv
# Out:
# "a","b","c"
# "1","2","3"
# "1","2","3","4"

# %%
import csv
f = open('./pydata-book/ch06/ex7.csv')
reader = csv.reader(f)

# %%
list(reader)
# Out:
# [['a', 'b', 'c'], ['1', '2', '3'], ['1', '2', '3', '4']]

# %%
#different line size, use python csv, more flexible form.
pd.read_csv('./pydata-book/ch06/ex7.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-89-99a36c03e158> in <module>()
# ----> 1 pd.read_csv('./pydata-book/ch06/ex7.csv')
#
# ...

# %%
lines = list(csv.reader(open('./pydata-book/ch06/ex7.csv')))

# %%
header, values = lines[0], lines[1:]

# %%
header, values
# Out:
# (['a', 'b', 'c'], [['1', '2', '3'], ['1', '2', '3', '4']])

# %%
data_dict = {h: v for h, v in zip(header, zip(*values))}
data_dict
# Out:
# {'a': ('1', '1'), 'b': ('2', '2'), 'c': ('3', '3')}

# %%
next(zip(*values))

# %%
next(zip (header, zip(*values)))
# Out:
# ('a', ('1', '1'))

# %%
print (*values)
# Out:
# ['1', '2', '3'] ['1', '2', '3', '4']

# %%
print (values)
# Out:
# [['1', '2', '3'], ['1', '2', '3', '4']]

# %%
1,2
# Out:
# (1, 2)

# %%
# open( , 'w', 'r')
# csv.reader
# csv.writer

f = open('./pydata-book/ch06/ex7.csv')
class my_dialect(csv.Dialect):
    lineterminator = '\n'
    delimiter = ';'
    quotechar = '"'
    quoting = csv.QUOTE_MINIMAL
    
reader = csv.reader(f, dialect = my_dialect)

# %%
list(reader)
# Out:
# [['a,"b","c"'], ['1,"2","3"'], ['1,"2","3","4"']]

# %%
with open('./pydata-book/mydata.csv', 'w') as f:
    writer = csv.writer(f, dialect = my_dialect)
    writer.writerow(('one', 'two', 'three'))
    writer.writerow(('1', '2', '3'))
    writer.writerow(('4', '5', '6'))
    writer.writerow(('7', '8', '9'))

# !cat ./pydata-book/mydata.csv
# Out:
# one;two;three
# 1;2;3
# 4;5;6
# 7;8;9

# %%
obj = """
{"name" : "Wes", 
"places_lived": ["United States", "Spain", "Germany"],
"pet":null,
"siblings": [{"name":"Scott", "age":25, "pet": "Zuko"},
{"name": "Katie", "age":33, "pet": "Cisco"}]
}
"""

import json
result = json.loads(obj)

result
# Out:
# {'name': 'Wes',
#  'pet': None,
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'siblings': [{'age': 25, 'name': 'Scott', 'pet': 'Zuko'},
#   {'age': 33, 'name': 'Katie', 'pet': 'Cisco'}]}

# %%
asjson = json.dumps(result)
type(result)
# Out:
# dict

# %%
type(asjson)
# Out:
# str

# %%
siblings = pd.DataFrame(result['siblings'], columns = ['name', 'age'])
siblings
# Out:
#     name  age
# 0  Scott   25
# 1  Katie   33
